# %%
# !pip install  langchain-groq
# !pip install streamlit
# Out:
# Requirement already satisfied: langchain-groq in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (0.3.4)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-groq) (0.3.67)
# Requirement already satisfied: groq<1,>=0.28.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-groq) (0.29.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (2.11.7)
# Requirement already satisfied: sniffio in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (4.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.28.0->langchain-groq) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.28.0->langchain-groq) (3.10)
# Requirement already satisfied: certifi in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.28.0->langchain-groq) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.28.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.28.0->langchain-groq) (0.16.0)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-groq) (0.4.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-groq) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-groq) (6.0.2)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-groq) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-groq) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.28.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.28.0->langchain-groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.28.0->langchain-groq) (0.4.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-groq) (3.10.18)
# Requirement already satisfied: requests<3,>=2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-groq) (2.32.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-groq) (0.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-groq) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-groq) (2.5.0)
# Requirement already satisfied: streamlit in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (1.46.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (2.2.6)
# Requirement already satisfied: packaging<26,>=20 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (2.3.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (4.14.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (1.44.0)
# Requirement already satisfied: colorama in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
# Install LangChain and dependencies
# !pip install langchain langchain-community langchain-core langchain-groq

# Install FAISS (for vector storage)
# !pip install faiss-cpu

# OpenAI (needed for some parts like token counting, even if not used directly)
# !pip install openai

# Streamlit (though not typically used in Colab, included because it's in your code)
# !pip install streamlit

# Ollama embeddings dependencies (requires HTTPX, etc.)
# !pip install httpx

# If you're using PDFs
# !pip install pypdf
# Out:
# Requirement already satisfied: langchain in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (0.3.26)
# Requirement already satisfied: langchain-community in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (0.3.26)
# Requirement already satisfied: langchain-core in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (0.3.67)
# Requirement already satisfied: langchain-groq in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (0.3.4)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain) (0.4.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-core) (4.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2->langchain) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-community) (3.12.13)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: groq<1,>=0.28.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langchain-groq) (0.29.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (0.28.1)
# Requirement already satisfied: sniffio in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from groq<1,>=0.28.0->langchain-groq) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.28.0->langchain-groq) (1.3.0)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.28.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.28.0->langchain-groq) (0.16.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langsmith>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.11.0-cp310-cp310-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from faiss-cpu) (2.2.6)
# Requirement already satisfied: packaging in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from faiss-cpu) (24.2)
# Using cached faiss_cpu-1.11.0-cp310-cp310-win_amd64.whl (15.0 MB)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0
# Collecting openai
#   Downloading openai-1.93.2-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.10.0-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from openai) (4.14.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: colorama in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.93.2-py3-none-any.whl (755 kB)
#    ---------------------------------------- 0.0/755.1 kB ? eta -:--:--
#    ---------------------------------------- 755.1/755.1 kB 8.0 MB/s eta 0:00:00
# Downloading jiter-0.10.0-cp310-cp310-win_amd64.whl (207 kB)
# Installing collected packages: jiter, openai
#
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    -------------------- ------------------- 1/2 [openai]
#    ---------------------------------------- 2/2 [openai]
#
# Successfully installed jiter-0.10.0 openai-1.93.2
# Requirement already satisfied: streamlit in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (1.46.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (2.2.6)
# Requirement already satisfied: packaging<26,>=20 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (2.3.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (4.14.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (1.44.0)
# Requirement already satisfied: colorama in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: httpx in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (0.28.1)
# Requirement already satisfied: anyio in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpx) (4.9.0)
# Requirement already satisfied: certifi in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpx) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpx) (1.0.9)
# Requirement already satisfied: idna in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpx) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpcore==1.*->httpx) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from anyio->httpx) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from anyio->httpx) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from anyio->httpx) (4.14.0)
# Collecting pypdf
#   Using cached pypdf-5.7.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pypdf) (4.14.0)
# Downloading pypdf-5.7.0-py3-none-any.whl (305 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-5.7.0

# %%
import streamlit as st
import os
from langchain_groq import ChatGroq
# from langchain_openai import OpenAIEmbeddings
from langchain_community.embeddings import OllamaEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import create_retrieval_chain
from langchain_community.vectorstores import FAISS
from langchain_community.document_loaders import PyPDFDirectoryLoader
# import openai

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
 ## Load the Groq API KEYS 

os.environ['GROQ_API_KEY']=os.getenv("GROQ_API_KEY")

## Once i got this i will able to use the Groq LLM.


groq_api_key=os.getenv("GROQ_API_KEY")

llm=ChatGroq(groq_api_key=groq_api_key,model_name="Llama3-8b-8192")

# %%
 ## In Prompt Template we will use the LLM to answer the question.
 
 prompt=ChatPromptTemplate.from_template(
    """
    Answer the questions based on the provided context only.
    Please provide the most accurate respone based on the question
    <context>
    {context}
    <context>
    Question:{input}

    """

)

# %% [markdown]
# ##### create_stuff_documents_chain
# ##### create_retrieval_chain
#
# This have some separate meaning for this type of context message

# %%
## SO WE HAVE TO CREATE THE EMBEDDINGS FOR THE QUESTION AND CONTEXT.

## I HAVE TO READ THE PDF FILES FROM THE DIRECTORY AND LOAD THEM.
## tHEN APPLY RECURSIVE CHARACTER TEXT SPLITTER TO SPLIT THE TEXT INTO SMALLER CHUNKS.

## THEN STORE THEM IN VECTOR STORE DATA BASE USING FAISS.

# %%
def create_vector_embedding():
    
## we specifically create the vector store db we need to create a session_id to load the pdf files.

    if "vectors" not in st.session_state:
        st.session_state.embeddings = OllamaEmbeddings()
        
        ## We need to load the pdf files from the directory.
        st.session_state.loader = PyPDFDirectoryLoader('PDfs')
        
        ## For load the pdf files we need to use the load method.
        st.session_state.docs = st.session_state.loader.load()
        
        ## We need to split the text into smaller chunks so that we can use them in the vector store.
        st.session_state.text_splitter=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200)
        
        ##Final documents after splitting the text into smaller chunks.
        ## We Saved here  the final documents in the session state.
        ## So that we can use them later in the retrieval chain.
        ## Have some memory of the documents.For the retrieval chain.
        
        st.session_state.final_docs = st.session_state.text_splitter.split_documents(st.session_state.docs[:50]) ## 50 is the number of documents we want to use.
        
        ## We need to create the vector store using the final documents and embeddings.
        st.session_state.vectors=FAISS.from_documents(st.session_state.final_documents,st.session_state.embeddings)

# %%
##st.tittle is used to display the title of the app.

st.title("RAG Document Q&A With Groq And Lama3")

## user_prompt is used to take the input from the user.
user_prompt=st.text_input("Enter your query from the research paper")


## st.button is used to create a button in the app.
if st.button("Document Embedding"):
    
    ## create_vector_embedding() ## This function will create the vector store database.
    create_vector_embedding()
    
    ##st,write is used to display the message in the app.
    st.write("Vector Database is ready")
# Out:
# 2025-07-08 22:54:43.100 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.034
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\ASUS\OneDrive\Desktop\sid\Sidd_project\venv\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-07-08 22:54:44.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.043 Session state does not function when running a script without `streamlit run`
# 2025-07-08 22:54:44.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 22:54:44.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ## What actuclly happend all the list of documents will specifically go and whatever specific input  we are giving it will go over Question:{input} here !

# %%
# import time

# %%
import time

if user_prompt:
    
    ## Create_stuff_documents_chain for Create a chain for passing a list of doc to a model.
    document_chain=create_stuff_documents_chain(llm,prompt)
    
    
    retriever=st.session_state.vectors.as_retriever()
    retrieval_chain=create_retrieval_chain(retriever,document_chain)
    
    start=time.process_time()
    response=retrieval_chain.invoke({'input':user_prompt})
    print(f"Response time :{time.process_time()-start}")

    st.write(response['answer'])

    ## With a streamlit expander
    with st.expander("Document similarity Search"):
        for i,doc in enumerate(response['context']):
            st.write(doc.page_content)
            st.write('------------------------')

# %%
pip install streamlit-jupyter
# Out:
# Collecting streamlit-jupyter
#   Downloading streamlit_jupyter-0.2.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting fastcore (from streamlit-jupyter)
#   Downloading fastcore-1.8.5-py3-none-any.whl.metadata (3.7 kB)
# Collecting ipywidgets==7.7.2 (from streamlit-jupyter)
#   Downloading ipywidgets-7.7.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting jupyter (from streamlit-jupyter)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting stqdm (from streamlit-jupyter)
#   Downloading stqdm-0.0.5-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: streamlit>=1.19 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit-jupyter) (1.46.1)
# Collecting tabulate (from streamlit-jupyter)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: tqdm in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit-jupyter) (4.67.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (6.29.5)
# Collecting ipython-genutils~=0.2.0 (from ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (5.14.3)
# Collecting widgetsnbextension~=3.6.0 (from ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading widgetsnbextension-3.6.10-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (8.37.0)
# Collecting jupyterlab-widgets<3,>=1.0.0 (from ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading jupyterlab_widgets-1.1.11-py3-none-any.whl.metadata (3.7 kB)
# Collecting notebook>=4.4.1 (from widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading notebook-7.4.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (1.8.14)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (1.6.0)
# Requirement already satisfied: packaging in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (24.2)
# Requirement already satisfied: psutil in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (27.0.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (6.5.1)
# Requirement already satisfied: colorama in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.4.6)
# Requirement already satisfied: decorator in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (4.14.0)
# Requirement already satisfied: wcwidth in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (307)
# Collecting jupyter-server<3,>=2.4.0 (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading jupyter_server-2.16.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.5,>=4.4.4 (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading jupyterlab-4.4.4-py3-none-any.whl.metadata (16 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (4.9.0)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading argon2_cffi-25.1.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (3.1.6)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbconvert>=6.4.4 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Collecting nbformat>=5.3.0 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: overrides>=5.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (7.7.0)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading prometheus_client-0.22.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pywinpty>=2.0.1 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading pywinpty-2.0.15-cp310-cp310-win_amd64.whl.metadata (5.2 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (1.8.0)
# Collecting async-lru>=1.0.0 (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.28.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (78.1.1)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.2.1)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (4.24.0)
# Requirement already satisfied: requests>=2.31 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.32.4)
# Requirement already satisfied: idna>=2.8 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (1.3.1)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: certifi in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.25.1)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading python_json_logger-3.3.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (6.0.2)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (3.0.0)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (4.13.4)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading mistune-3.1.3-py3-none-any.whl.metadata (1.8 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: six>=1.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.5.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (2.2.6)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (2.3.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (20.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (0.10.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (0.9.1)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (1.44.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit-jupyter) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit-jupyter) (5.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (2025.2)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Using cached cffi-1.17.1-cp310-cp310-win_amd64.whl.metadata (1.6 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.7)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading types_python_dateutil-2.9.0.20250708-py3-none-any.whl.metadata (1.9 kB)
# Collecting jupyter-console (from jupyter->streamlit-jupyter)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: executing>=1.2.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.2.3)
# Downloading streamlit_jupyter-0.2.1-py3-none-any.whl (13 kB)
# Downloading ipywidgets-7.7.2-py2.py3-none-any.whl (123 kB)
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Downloading jupyterlab_widgets-1.1.11-py3-none-any.whl (246 kB)
# Downloading widgetsnbextension-3.6.10-py2.py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 7.5 MB/s eta 0:00:00
# Downloading notebook-7.4.4-py3-none-any.whl (14.3 MB)
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/14.3 MB 10.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.9/14.3 MB 9.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.8/14.3 MB 9.5 MB/s eta 0:00:01
#    --------------------- ------------------ 7.6/14.3 MB 9.2 MB/s eta 0:00:01
#    --------------------------- ------------ 9.7/14.3 MB 9.0 MB/s eta 0:00:01
#    -------------------------------- ------- 11.5/14.3 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  14.2/14.3 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 14.3/14.3 MB 9.1 MB/s eta 0:00:00
# Downloading jupyter_server-2.16.0-py3-none-any.whl (386 kB)
# Downloading jupyterlab-4.4.4-py3-none-any.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    -------- ------------------------------- 2.6/12.3 MB 12.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.2/12.3 MB 12.3 MB/s eta 0:00:01
#    --------------------------- ------------ 8.4/12.3 MB 13.3 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.3 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 12.6 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/10.2 MB 11.2 MB/s eta 0:00:01
#    -------------------- ------------------- 5.2/10.2 MB 12.3 MB/s eta 0:00:01
#    ------------------------------- -------- 8.1/10.2 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.2 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 11.8 MB/s eta 0:00:00
# Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Downloading mistune-3.1.3-py3-none-any.whl (53 kB)
# Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading prometheus_client-0.22.1-py3-none-any.whl (58 kB)
# Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Downloading pywinpty-2.0.15-cp310-cp310-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 10.4 MB/s eta 0:00:00
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Using cached cffi-1.17.1-cp310-cp310-win_amd64.whl (181 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading fastcore-1.8.5-py3-none-any.whl (79 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
# Downloading types_python_dateutil-2.9.0.20250708-py3-none-any.whl (17 kB)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading stqdm-0.0.5-py3-none-any.whl (11 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, ipython-genutils, fastjsonschema, webcolors, uri-template, types-python-dateutil, tinycss2, tabulate, send2trash, rfc3986-validator, rfc3339-validator, pywinpty, python-json-logger, pycparser, prometheus-client, pandocfilters, mistune, jupyterlab-widgets, jupyterlab-pygments, json5, fqdn, fastcore, defusedxml, bleach, babel, async-lru, terminado, cffi, arrow, jupyter-server-terminals, isoduration, argon2-cffi-bindings, nbformat, jupyter-console, argon2-cffi, nbclient, jupyter-events, stqdm, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, widgetsnbextension, ipywidgets, jupyter, streamlit-jupyter
#
#    ----------------------------------------  0/49 [webencodings]
#     ---------------------------------------  1/49 [ipython-genutils]
#     ---------------------------------------  1/49 [ipython-genutils]
#    - --------------------------------------  2/49 [fastjsonschema]
#    - --------------------------------------  2/49 [fastjsonschema]
#    -- -------------------------------------  3/49 [webcolors]
#    --- ------------------------------------  4/49 [uri-template]
#    ---- -----------------------------------  5/49 [types-python-dateutil]
#    ---- -----------------------------------  6/49 [tinycss2]
#    ---- -----------------------------------  6/49 [tinycss2]
#    ----- ----------------------------------  7/49 [tabulate]
#    ----- ----------------------------------  7/49 [tabulate]
#    ------ ---------------------------------  8/49 [send2trash]
#    ------ ---------------------------------  8/49 [send2trash]
#    ------ ---------------------------------  8/49 [send2trash]
#    ------ ---------------------------------  8/49 [send2trash]
#    -------- ------------------------------- 11/49 [pywinpty]
#    -------- ------------------------------- 11/49 [pywinpty]
#    --------- ------------------------------ 12/49 [python-json-logger]
#    --------- ------------------------------ 12/49 [python-json-logger]
#    ---------- ----------------------------- 13/49 [pycparser]
#    ---------- ----------------------------- 13/49 [pycparser]
#    ---------- ----------------------------- 13/49 [pycparser]
#    ---------- ----------------------------- 13/49 [pycparser]
#    ---------- ----------------------------- 13/49 [pycparser]
#    ----------- ---------------------------- 14/49 [prometheus-client]
#    ----------- ---------------------------- 14/49 [prometheus-client]
#    ----------- ---------------------------- 14/49 [prometheus-client]
#    ----------- ---------------------------- 14/49 [prometheus-client]
#    ------------- -------------------------- 16/49 [mistune]
#    ------------- -------------------------- 16/49 [mistune]
#    ------------- -------------------------- 16/49 [mistune]
#    ------------- -------------------------- 16/49 [mistune]
#    ------------- -------------------------- 16/49 [mistune]
#    ------------- -------------------------- 16/49 [mistune]
#    ------------- -------------------------- 16/49 [mistune]
#    ------------- -------------------------- 17/49 [jupyterlab-widgets]
#    -------------- ------------------------- 18/49 [jupyterlab-pygments]
#    --------------- ------------------------ 19/49 [json5]
#    --------------- ------------------------ 19/49 [json5]
#    ---------------- ----------------------- 20/49 [fqdn]
#    ----------------- ---------------------- 21/49 [fastcore]
#    ----------------- ---------------------- 21/49 [fastcore]
#    ----------------- ---------------------- 21/49 [fastcore]
#    ----------------- ---------------------- 21/49 [fastcore]
#    ----------------- ---------------------- 21/49 [fastcore]
#    ----------------- ---------------------- 21/49 [fastcore]
#    ----------------- ---------------------- 21/49 [fastcore]
#    ----------------- ---------------------- 22/49 [defusedxml]
#    ----------------- ---------------------- 22/49 [defusedxml]
#    ------------------ --------------------- 23/49 [bleach]
#    ------------------ --------------------- 23/49 [bleach]
#    ------------------ --------------------- 23/49 [bleach]
#    ------------------ --------------------- 23/49 [bleach]
#    ------------------ --------------------- 23/49 [bleach]
#    ------------------ --------------------- 23/49 [bleach]
#    ------------------ --------------------- 23/49 [bleach]
#    ------------------ --------------------- 23/49 [bleach]
#    ------------------ --------------------- 23/49 [bleach]
#    ------------------ --------------------- 23/49 [bleach]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    ------------------- -------------------- 24/49 [babel]
#    --------------------- ------------------ 26/49 [terminado]
#    ---------------------- ----------------- 27/49 [cffi]
#    ---------------------- ----------------- 27/49 [cffi]
#    ---------------------- ----------------- 27/49 [cffi]
#    ---------------------- ----------------- 27/49 [cffi]
#    ---------------------- ----------------- 28/49 [arrow]
#    ---------------------- ----------------- 28/49 [arrow]
#    ----------------------- ---------------- 29/49 [jupyter-server-terminals]
#    ----------------------- ---------------- 29/49 [jupyter-server-terminals]
#    ------------------------ --------------- 30/49 [isoduration]
#    ------------------------ --------------- 30/49 [isoduration]
#    -------------------------- ------------- 32/49 [nbformat]
#    -------------------------- ------------- 32/49 [nbformat]
#    -------------------------- ------------- 32/49 [nbformat]
#    -------------------------- ------------- 32/49 [nbformat]
#    -------------------------- ------------- 32/49 [nbformat]
#    -------------------------- ------------- 32/49 [nbformat]
#    -------------------------- ------------- 32/49 [nbformat]
#    -------------------------- ------------- 32/49 [nbformat]
#    -------------------------- ------------- 33/49 [jupyter-console]
#    -------------------------- ------------- 33/49 [jupyter-console]
#    -------------------------- ------------- 33/49 [jupyter-console]
#    --------------------------- ------------ 34/49 [argon2-cffi]
#    --------------------------- ------------ 34/49 [argon2-cffi]
#    ---------------------------- ----------- 35/49 [nbclient]
#    ---------------------------- ----------- 35/49 [nbclient]
#    ----------------------------- ---------- 36/49 [jupyter-events]
#    ----------------------------- ---------- 36/49 [jupyter-events]
#    ----------------------------- ---------- 36/49 [jupyter-events]
#    ------------------------------ --------- 37/49 [stqdm]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 38/49 [nbconvert]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    ------------------------------- -------- 39/49 [jupyter-server]
#    -------------------------------- ------- 40/49 [notebook-shim]
#    -------------------------------- ------- 40/49 [notebook-shim]
#    --------------------------------- ------ 41/49 [jupyterlab-server]
#    --------------------------------- ------ 41/49 [jupyterlab-server]
#    --------------------------------- ------ 41/49 [jupyterlab-server]
#    --------------------------------- ------ 41/49 [jupyterlab-server]
#    ---------------------------------- ----- 42/49 [jupyter-lsp]
#    ---------------------------------- ----- 42/49 [jupyter-lsp]
#    ---------------------------------- ----- 42/49 [jupyter-lsp]
#    ---------------------------------- ----- 42/49 [jupyter-lsp]
#    ---------------------------------- ----- 42/49 [jupyter-lsp]
#    ---------------------------------- ----- 42/49 [jupyter-lsp]
#    ---------------------------------- ----- 42/49 [jupyter-lsp]
#    ---------------------------------- ----- 42/49 [jupyter-lsp]
#    ---------------------------------- ----- 42/49 [jupyter-lsp]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 43/49 [jupyterlab]
#    ----------------------------------- ---- 44/49 [notebook]
#    ----------------------------------- ---- 44/49 [notebook]
#    ----------------------------------- ---- 44/49 [notebook]
#    ----------------------------------- ---- 44/49 [notebook]
#    ----------------------------------- ---- 44/49 [notebook]
#    ----------------------------------- ---- 44/49 [notebook]
#    ----------------------------------- ---- 44/49 [notebook]
#    ----------------------------------- ---- 44/49 [notebook]
#    ----------------------------------- ---- 44/49 [notebook]
#    ----------------------------------- ---- 44/49 [notebook]
#    ----------------------------------- ---- 44/49 [notebook]
#    ----------------------------------- ---- 44/49 [notebook]
#    ----------------------------------- ---- 44/49 [notebook]
#    ------------------------------------ --- 45/49 [widgetsnbextension]
#    ------------------------------------ --- 45/49 [widgetsnbextension]
#    ------------------------------------- -- 46/49 [ipywidgets]
#    ------------------------------------- -- 46/49 [ipywidgets]
#    ------------------------------------- -- 46/49 [ipywidgets]
#    ------------------------------------- -- 46/49 [ipywidgets]
#    ------------------------------------- -- 46/49 [ipywidgets]
#    ------------------------------------- -- 46/49 [ipywidgets]
#    ------------------------------------- -- 46/49 [ipywidgets]
#    ------------------------------------- -- 46/49 [ipywidgets]
#    ------------------------------------- -- 46/49 [ipywidgets]
#    -------------------------------------- - 47/49 [jupyter]
#    ---------------------------------------  48/49 [streamlit-jupyter]
#    ---------------------------------------- 49/49 [streamlit-jupyter]
#
# Successfully installed argon2-cffi-25.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.5 babel-2.17.0 bleach-6.2.0 cffi-1.17.1 defusedxml-0.7.1 fastcore-1.8.5 fastjsonschema-2.21.1 fqdn-1.5.1 ipython-genutils-0.2.0 ipywidgets-7.7.2 isoduration-20.11.0 json5-0.12.0 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.16.0 jupyter-server-terminals-0.5.3 jupyterlab-4.4.4 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab-widgets-1.1.11 mistune-3.1.3 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 notebook-7.4.4 notebook-shim-0.2.4 pandocfilters-1.5.1 prometheus-client-0.22.1 pycparser-2.22 python-json-logger-3.3.0 pywinpty-2.0.15 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.3 stqdm-0.0.5 streamlit-jupyter-0.2.1 tabulate-0.9.0 terminado-0.18.1 tinycss2-1.4.0 types-python-dateutil-2.9.0.20250708 uri-template-1.3.0 webcolors-24.11.1 webencodings-0.5.1 widgetsnbextension-3.6.10
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install streamlit streamlit-jupyter
# Out:
# Requirement already satisfied: streamlit in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (1.46.1)
# Requirement already satisfied: streamlit-jupyter in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (0.2.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (2.2.6)
# Requirement already satisfied: packaging<26,>=20 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (2.3.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (4.14.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from altair<6,>=4.0->streamlit) (1.44.0)
# Requirement already satisfied: colorama in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.6.15)
# Requirement already satisfied: fastcore in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit-jupyter) (1.8.5)
# Requirement already satisfied: ipywidgets==7.7.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit-jupyter) (7.7.2)
# Requirement already satisfied: jupyter in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit-jupyter) (1.1.1)
# Requirement already satisfied: stqdm in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit-jupyter) (0.0.5)
# Requirement already satisfied: tabulate in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit-jupyter) (0.9.0)
# Requirement already satisfied: tqdm in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from streamlit-jupyter) (4.67.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (6.29.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (8.37.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (1.1.11)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (7.4.4)
# Requirement already satisfied: comm>=0.1.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (1.8.14)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (1.6.0)
# Requirement already satisfied: psutil in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (27.0.0)
# Requirement already satisfied: decorator in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (307)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (4.4.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.2.5)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (78.1.1)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.2.1)
# Requirement already satisfied: babel>=2.10 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.12.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (21.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.5,>=4.4.4->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.16.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.21.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.2->streamlit-jupyter) (2.9.0.20250708)
# Requirement already satisfied: jupyter-console in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from jupyter->streamlit-jupyter) (6.6.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\asus\onedrive\desktop\sid\sidd_project\venv\lib\site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
## Load the Image from a file. 

from PIL import Image

img = Image.open('Result\Screenshot (130).png')
img.show()

# %%
img.show()
